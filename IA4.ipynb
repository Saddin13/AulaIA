# %% [markdown]
# <a href="https://colab.research.google.com/github/Saddin13/AulaIA/blob/main/IA4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# A aula 4 foi basicamente para melhora do codigo da AULA 3

# %%
print("A aula 4, foi uma continuacao da aula 3")
