# %% [markdown]
# <a href="https://colab.research.google.com/github/Saddin13/AulaIA/blob/main/AI5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
import pandas as pd

# %%
import pandas as pd

df = pd.read_csv("precos-gasolina-etanol-12.csv", sep=';')

#converter virgula para ponto
df["Valor de Venda"] = df["Valor de Venda"].str.replace(",", ".").astype(float)
#Data padrao Ingles
df["Data da Coleta"] = pd.to_datetime(df["Data da Coleta"], dayfirst=True)

df.head(15)
# Out:
#    Regiao - Sigla Estado - Sigla  Municipio  \
# 0              NE             AL  ARAPIRACA
# 1              NE             AL  ARAPIRACA
# 2              NE             AL  ARAPIRACA
# 3              NE             AL  ARAPIRACA
# 4              NE             AL  ARAPIRACA
# 5              NE             AL  ARAPIRACA
# 6              NE             AL  ARAPIRACA
# 7              NE             AL  ARAPIRACA
# 8              NE             AL  ARAPIRACA
# 9              NE             AL  ARAPIRACA
# 10             NE             AL  ARAPIRACA
# 11             NE             AL  ARAPIRACA
# 12             NE             AL  ARAPIRACA
# 13             NE             AL  ARAPIRACA
# 14              N             AP     MACAPA
#
#                                          Revenda      CNPJ da Revenda  \
# 0                    AUTO POSTO M M GARROTE LTDA   08.738.994/0001-50
# 1                    AUTO POSTO M M GARROTE LTDA   08.738.994/0001-50
# 2                    AUTO POSTO M M GARROTE LTDA   08.738.994/0001-50
# 3                   AUTO POSTO MASSARANDUBA LTDA   07.248.398/0001-29
# 4                   AUTO POSTO MASSARANDUBA LTDA   07.248.398/0001-29
# 5                   AUTO POSTO MASSARANDUBA LTDA   07.248.398/0001-29
# 6                  POSTO ATLANTIC CONFIANCA LTDA   08.461.170/0001-85
# 7                      POSTO E HOTEL DI'VAN LTDA   24.313.645/0001-42
# 8   DISTRIBUIDORA DE VEICULOS CONFIANCA LIMITADA   12.396.339/0001-38
# 9   DISTRIBUIDORA DE VEICULOS CONFIANCA LIMITADA   12.396.339/0001-38
# 10  DISTRIBUIDORA DE VEICULOS CONFIANCA LIMITADA   12.396.339/0001-38
# 11                  IBN PINTO E SILVA & CIA LTDA   01.242.690/0001-58
# 12                  IBN PINTO E SILVA & CIA LTDA   01.242.690/0001-58
# 13                  IBN PINTO E SILVA & CIA LTDA   01.242.690/0001-58
# 14                        MACHADO & ANDRADE LTDA   08.945.482/0001-64
#
#                         Nome da Rua Numero Rua Complemento             Bairro  \
# 0                    RODOVIA AL-220       5848    KM    96        BOM SUCESSO
# 1                    RODOVIA AL-220       5848    KM    96        BOM SUCESSO
# 2                    RODOVIA AL-220       5848    KM    96        BOM SUCESSO
# 3                    RODOVIA AL 220       4698         NaN           PLANALTO
# 4                    RODOVIA AL 220       4698         NaN           PLANALTO
# 5                    RODOVIA AL 220       4698         NaN           PLANALTO
# 6            RUA QUINZE DE NOVEMBRO        470         NaN             CENTRO
# 7   AVENIDA ANTONIO SERMEAO L FILHO        406         NaN    JARDIM TROPICAL
# 8            RUA QUINZE DE NOVEMBRO        451         NaN           BRASILIA
# 9            RUA QUINZE DE NOVEMBRO        451         NaN           BRASILIA
# 10           RUA QUINZE DE NOVEMBRO        451         NaN           BRASILIA
# 11                   RODOVIA AL-110        678    KM    70        CANAFISTULA
# 12                   RODOVIA AL-110        678    KM    70        CANAFISTULA
# 13                   RODOVIA AL-110        678    KM    70        CANAFISTULA
# 14     RODOVIA JUSCELINO KUBITSCHEK        841         NaN  JARDIM MARCO ZERO
#
#           Cep             Produto Data da Coleta  Valor de Venda  \
# 0   57309-035            GASOLINA     2025-12-01            6.14
# 1   57309-035  GASOLINA ADITIVADA     2025-12-01            6.14
# 2   57309-035              ETANOL     2025-12-01            4.79
# 3   57308-000            GASOLINA     2025-12-01            6.19
# 4   57308-000  GASOLINA ADITIVADA     2025-12-01            6.19
# 5   57308-000              ETANOL     2025-12-01            4.89
# 6   57300-340            GASOLINA     2025-12-01            6.09
# 7   57304-820            GASOLINA     2025-12-01            6.19
# 8   57313-015            GASOLINA     2025-12-01            6.09
# 9   57313-015  GASOLINA ADITIVADA     2025-12-01            6.49
# 10  57313-015              ETANOL     2025-12-01            5.09
# 11  57302-802            GASOLINA     2025-12-01            6.29
# 12  57302-802  GASOLINA ADITIVADA     2025-12-01            6.49
# 13  57302-802              ETANOL     2025-12-01            4.99
# 14  68903-014            GASOLINA     2025-12-01            6.04
#
#     Valor de Compra Unidade de Medida  Bandeira
# 0               NaN        R$ / litro     VIBRA
# 1               NaN        R$ / litro     VIBRA
# 2               NaN        R$ / litro     VIBRA
# 3               NaN        R$ / litro    BRANCA
# 4               NaN        R$ / litro    BRANCA
# 5               NaN        R$ / litro    BRANCA
# 6               NaN        R$ / litro  IPIRANGA
# 7               NaN        R$ / litro     VIBRA
# 8               NaN        R$ / litro    RAIZEN
# 9               NaN        R$ / litro    RAIZEN
# 10              NaN        R$ / litro    RAIZEN
# 11              NaN        R$ / litro    BRANCA
# 12              NaN        R$ / litro    BRANCA
# 13              NaN        R$ / litro    BRANCA
# 14              NaN        R$ / litro  IPIRANGA

# %%
df.describe()
# Out:
#                       Data da Coleta  Valor de Venda  Valor de Compra
# count                          52336    52336.000000              0.0
# mean   2025-12-15 14:40:57.597065216        5.728101              NaN
# min              2025-12-01 00:00:00        3.490000              NaN
# 25%              2025-12-08 00:00:00        4.790000              NaN
# 50%              2025-12-16 00:00:00        5.990000              NaN
# 75%              2025-12-23 00:00:00        6.390000              NaN
# max              2025-12-31 00:00:00        9.590000              NaN
# std                              NaN        0.908264              NaN

# %%
df_produto = df.groupby(["Produto","Estado - Sigla"])["Valor de Venda"]
df_produto.describe()
# Out:
#                                     count      mean       std   min     25%  \
# Produto            Estado - Sigla
# ETANOL             AC                33.0  5.373939  0.307276  5.09  5.1900
#                    AL               206.0  4.972282  0.176188  4.39  4.8900
#                    AM               181.0  5.475801  0.046631  5.39  5.4800
#                    AP                 4.0  5.727500  0.125000  5.54  5.7275
#                    BA               892.0  4.774249  0.346492  3.99  4.5500
# ...                                   ...       ...       ...   ...     ...
# GASOLINA ADITIVADA RS              1500.0  6.420920  0.284580  5.75  6.2500
